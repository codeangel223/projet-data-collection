# %% [markdown]
# # Traitement & Nettoyages des donnees provenant de webscrapper

# %%
import pandas as pd # type: ignore
import numpy as np # type: ignore

# %% [markdown]
# ## Je lis mes datasets

# %%
chiens = pd.read_csv("./data/chiens.csv")
moutons = pd.read_csv("./data/moutons.csv")
volailles = pd.read_csv("./data/volailles.csv")
other_animals = pd.read_csv("./data/other-animals.csv")

# %% [markdown]
# # Tratement du datasets Motos

# %% [markdown]
# ## Obsertations

# %%
chiens.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0      1739070143-1  https://sn.coinafrique.com/categorie/chiens?pa...
# 1      1739070148-2  https://sn.coinafrique.com/categorie/chiens?pa...
# 2      1739070153-3  https://sn.coinafrique.com/categorie/chiens?pa...
# 3      1739070157-4  https://sn.coinafrique.com/categorie/chiens?pa...
# 4      1739070162-5  https://sn.coinafrique.com/categorie/chiens?pa...
#
#                         links  \
# 0  Pitt Bull red nose femelle
# 1              Chiots Pitbull
# 2              Caniche bichon
# 3              Chiot Boerboel
# 4            Pitbull Red Nose
#
#                                           links-href  \
# 0  https://sn.coinafrique.com/annonce/chiens/pitt...
# 1  https://sn.coinafrique.com/annonce/chiens/chio...
# 2  https://sn.coinafrique.com/annonce/chiens/cani...
# 3  https://sn.coinafrique.com/annonce/chiens/chio...
# 4  https://sn.coinafrique.com/annonce/chiens/pitb...
#
#                          name             price  \
# 0  Pitt Bull red nose femelle  Prix sur demande
# 1              Chiots Pitbull       250 000 CFA
# 2              Caniche bichon       200 000 CFA
# 3              Chiot Boerboel       450 000 CFA
# 4            Pitbull Red Nose       220 000 CFA
#
#                               adresse  \
# 0                      Dakar, Sénégal
# 1          Grand Yoff, Dakar, Sénégal
# 2  Mermoz-Sacré Coeur, Dakar, Sénégal
# 3  Mermoz-Sacré Coeur, Dakar, Sénégal
# 4  Mermoz-Sacré Coeur, Dakar, Sénégal
#
#                                       image-link-src
# 0  background-image: url("https://images.coinafri...
# 1  background-image: url("https://images.coinafri...
# 2  background-image: url("https://images.coinafri...
# 3  background-image: url("https://images.coinafri...
# 4  background-image: url("https://images.coinafri...

# %%
chiens["links-href"].iloc[0] 
# C'est pour voir si cette feature correspond au lien d'access de chaque page d'article -> c'est le cas
# Out:
# 'https://sn.coinafrique.com/annonce/chiens/pitt-bull-red-nose-femelle-742530'

# %%
chiens.columns
# Out:
# Index(['web-scraper-order', 'web-scraper-start-url', 'links', 'links-href',
#        'name', 'price', 'adresse', 'image-link-src'],
#       dtype='object')

# %%
chiens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   web-scraper-order      801 non-null    object
#  1   web-scraper-start-url  801 non-null    object
#  2   links                  801 non-null    object
#  3   links-href             801 non-null    object
#  4   name                   801 non-null    object
#  5   price                  801 non-null    object
#  6   adresse                801 non-null    object
#  7   image-link-src         801 non-null    object
# dtypes: object(8)
# memory usage: 50.2+ KB

# %%
chiens.describe().transpose()
# Out:
#                       count unique  \
# web-scraper-order       801    801
# web-scraper-start-url   801     10
# links                   801    389
# links-href              801    801
# name                    801    389
# price                   801     78
# adresse                 801     52
# image-link-src          801    801
#
#                                                                      top freq
# web-scraper-order                                         1739073284-801    1
# web-scraper-start-url  https://sn.coinafrique.com/categorie/chiens?pa...   84
# links                                              Chiot Berger Allemand   35
# links-href             https://sn.coinafrique.com/annonce/chiens/chio...    1
# name                                               Chiot Berger Allemand   35
# price                                                   Prix sur demande  155
# adresse                                                   Dakar, Sénégal  173
# image-link-src         background-image: url("https://images.coinafri...    1

# %% [markdown]
# ### <font color="yellow"> Traitement gnrale

# %%
all_df = {"chiens": chiens, "moutons": moutons, "volailles": volailles, "other-animals": other_animals}

# %%
# Je redefinis mes col pour prendre que les cols concernees
new_columns = ['links-href', 'name', 'price', 'adresse', 'image-link-src']

for key, df in all_df.items():

    new_df = df[new_columns]

    # Je renomme la col image-link-src to image-link, et links-href to page-link
    new_df = new_df.rename({'image-link-src': "image-link","links-href": "page-link"}, axis=1)

    # je valide dans le all_df original
    all_df[key] = new_df

# %%
# un coup d'oeil
all_df["chiens"].head()
# Out:
#                                            page-link  \
# 0  https://sn.coinafrique.com/annonce/chiens/pitt...
# 1  https://sn.coinafrique.com/annonce/chiens/chio...
# 2  https://sn.coinafrique.com/annonce/chiens/cani...
# 3  https://sn.coinafrique.com/annonce/chiens/chio...
# 4  https://sn.coinafrique.com/annonce/chiens/pitb...
#
#                          name             price  \
# 0  Pitt Bull red nose femelle  Prix sur demande
# 1              Chiots Pitbull       250 000 CFA
# 2              Caniche bichon       200 000 CFA
# 3              Chiot Boerboel       450 000 CFA
# 4            Pitbull Red Nose       220 000 CFA
#
#                               adresse  \
# 0                      Dakar, Sénégal
# 1          Grand Yoff, Dakar, Sénégal
# 2  Mermoz-Sacré Coeur, Dakar, Sénégal
# 3  Mermoz-Sacré Coeur, Dakar, Sénégal
# 4  Mermoz-Sacré Coeur, Dakar, Sénégal
#
#                                           image-link
# 0  background-image: url("https://images.coinafri...
# 1  background-image: url("https://images.coinafri...
# 2  background-image: url("https://images.coinafri...
# 3  background-image: url("https://images.coinafri...
# 4  background-image: url("https://images.coinafri...

# %% [markdown]
# #### Nettoyage des textes

# %%
chiens = all_df["chiens"]

# %%
chiens.head()
# Out:
#                                            page-link  \
# 0  https://sn.coinafrique.com/annonce/chiens/pitt...
# 1  https://sn.coinafrique.com/annonce/chiens/chio...
# 2  https://sn.coinafrique.com/annonce/chiens/cani...
# 3  https://sn.coinafrique.com/annonce/chiens/chio...
# 4  https://sn.coinafrique.com/annonce/chiens/pitb...
#
#                          name             price  \
# 0  Pitt Bull red nose femelle  Prix sur demande
# 1              Chiots Pitbull       250 000 CFA
# 2              Caniche bichon       200 000 CFA
# 3              Chiot Boerboel       450 000 CFA
# 4            Pitbull Red Nose       220 000 CFA
#
#                               adresse  \
# 0                      Dakar, Sénégal
# 1          Grand Yoff, Dakar, Sénégal
# 2  Mermoz-Sacré Coeur, Dakar, Sénégal
# 3  Mermoz-Sacré Coeur, Dakar, Sénégal
# 4  Mermoz-Sacré Coeur, Dakar, Sénégal
#
#                                           image-link
# 0  background-image: url("https://images.coinafri...
# 1  background-image: url("https://images.coinafri...
# 2  background-image: url("https://images.coinafri...
# 3  background-image: url("https://images.coinafri...
# 4  background-image: url("https://images.coinafri...

# %%
def get_price_numeric(price:str):
    return "".join(price.split(" ")[:-1])

# %%
# Mettre en forme "marque"
# Separer le price en deux col: "price -> float" ete "devise" -> object
for key, df in all_df.items():

    try:
        price = df["price"].apply(get_price_numeric)
        devise = df["price"].str.split(" ").str[-1]
    except Exception as e:
        price = "Sur demande"
        devise = np.nan

    all_df[key]["price"] = price
    all_df[key]["devise"] = devise

    # Je profite pour juste recuperer le nom du quartier dans "adresse"
    quartier = df["adresse"].str.split(" ").str[0]
    ville = df["adresse"].str.split(" ").str[-2]
    pays = df["adresse"].str.split(" ").str[-1]

    all_df[key]["quartier"] = quartier
    all_df[key]["ville"] = ville
    all_df[key]["pays"] = pays

    all_df[key]["adresse"] = df["adresse"].str.strip()

# %%
chiens["devise"] = chiens["devise"].replace("demande", "Non défini")
chiens["price"] = chiens["price"].replace("Prixsur", "Sur demande")

# %%
chiens.head()
# Out:
#                                            page-link  \
# 0  https://sn.coinafrique.com/annonce/chiens/pitt...
# 1  https://sn.coinafrique.com/annonce/chiens/chio...
# 2  https://sn.coinafrique.com/annonce/chiens/cani...
# 3  https://sn.coinafrique.com/annonce/chiens/chio...
# 4  https://sn.coinafrique.com/annonce/chiens/pitb...
#
#                          name        price  \
# 0  Pitt Bull red nose femelle  Sur demande
# 1              Chiots Pitbull       250000
# 2              Caniche bichon       200000
# 3              Chiot Boerboel       450000
# 4            Pitbull Red Nose       220000
#
#                               adresse  \
# 0                      Dakar, Sénégal
# 1          Grand Yoff, Dakar, Sénégal
# 2  Mermoz-Sacré Coeur, Dakar, Sénégal
# 3  Mermoz-Sacré Coeur, Dakar, Sénégal
# 4  Mermoz-Sacré Coeur, Dakar, Sénégal
#
#                                           image-link      devise  \
# 0  background-image: url("https://images.coinafri...  Non défini
# 1  background-image: url("https://images.coinafri...         CFA
# 2  background-image: url("https://images.coinafri...         CFA
# 3  background-image: url("https://images.coinafri...         CFA
# 4  background-image: url("https://images.coinafri...         CFA
#
#        quartier   ville     pays
# 0        Dakar,  Dakar,  Sénégal
# 1         Grand  Dakar,  Sénégal
# 2  Mermoz-Sacré  Dakar,  Sénégal
# 3  Mermoz-Sacré  Dakar,  Sénégal
# 4  Mermoz-Sacré  Dakar,  Sénégal

# %%
chiens[["name", "price", "devise", "quartier", "ville", "pays", "adresse"]]
# Out:
#                            name        price      devise      quartier  \
# 0    Pitt Bull red nose femelle  Sur demande  Non défini        Dakar,
# 1                Chiots Pitbull       250000         CFA         Grand
# 2                Caniche bichon       200000         CFA  Mermoz-Sacré
# 3                Chiot Boerboel       450000         CFA  Mermoz-Sacré
# 4              Pitbull Red Nose       220000         CFA  Mermoz-Sacré
# ..                          ...          ...         ...           ...
# 796                       Chiot       500000         CFA         Yoff,
# 797            Chiot Rottweiler       350000         CFA  Sacré-Coeur,
# 798                 Chiot Husky       350000         CFA  Sacré-Coeur,
# 799             Chiot Chihuahua       150000         CFA   Diamniadio,
# 800       Chiot Berger Allemand       350000         CFA   Diamniadio,
#
#            ville     pays                             adresse
# 0         Dakar,  Sénégal                      Dakar, Sénégal
# 1         Dakar,  Sénégal          Grand Yoff, Dakar, Sénégal
# 2         Dakar,  Sénégal  Mermoz-Sacré Coeur, Dakar, Sénégal
# 3         Dakar,  Sénégal  Mermoz-Sacré Coeur, Dakar, Sénégal
# 4         Dakar,  Sénégal  Mermoz-Sacré Coeur, Dakar, Sénégal
# ..           ...      ...                                 ...
# 796       Dakar,  Sénégal                Yoff, Dakar, Sénégal
# 797       Dakar,  Sénégal         Sacré-Coeur, Dakar, Sénégal
# 798       Dakar,  Sénégal         Sacré-Coeur, Dakar, Sénégal
# 799  Diamniadio,  Sénégal                 Diamniadio, Sénégal
# 800  Diamniadio,  Sénégal                 Diamniadio, Sénégal
#
# [801 rows x 7 columns]

# %%
chiens.head()
# Out:
#                                            page-link  \
# 0  https://sn.coinafrique.com/annonce/chiens/pitt...
# 1  https://sn.coinafrique.com/annonce/chiens/chio...
# 2  https://sn.coinafrique.com/annonce/chiens/cani...
# 3  https://sn.coinafrique.com/annonce/chiens/chio...
# 4  https://sn.coinafrique.com/annonce/chiens/pitb...
#
#                          name        price  \
# 0  Pitt Bull red nose femelle  Sur demande
# 1              Chiots Pitbull       250000
# 2              Caniche bichon       200000
# 3              Chiot Boerboel       450000
# 4            Pitbull Red Nose       220000
#
#                               adresse  \
# 0                      Dakar, Sénégal
# 1          Grand Yoff, Dakar, Sénégal
# 2  Mermoz-Sacré Coeur, Dakar, Sénégal
# 3  Mermoz-Sacré Coeur, Dakar, Sénégal
# 4  Mermoz-Sacré Coeur, Dakar, Sénégal
#
#                                           image-link      devise  \
# 0  background-image: url("https://images.coinafri...  Non défini
# 1  background-image: url("https://images.coinafri...         CFA
# 2  background-image: url("https://images.coinafri...         CFA
# 3  background-image: url("https://images.coinafri...         CFA
# 4  background-image: url("https://images.coinafri...         CFA
#
#        quartier   ville     pays
# 0        Dakar,  Dakar,  Sénégal
# 1         Grand  Dakar,  Sénégal
# 2  Mermoz-Sacré  Dakar,  Sénégal
# 3  Mermoz-Sacré  Dakar,  Sénégal
# 4  Mermoz-Sacré  Dakar,  Sénégal

# %% [markdown]
# # Traitement des valeurs manquantes

# %%
for key, df in all_df.items():
    print(f"{key}\n", df.isnull().sum())
# Out:
# chiens
#  page-link     0
# name          0
# price         0
# adresse       0
# image-link    0
# devise        0
# quartier      0
# ville         0
# pays          0
# dtype: int64
# moutons
#  page-link     0
# name          0
# price         0
# adresse       0
# image-link    0
# devise        0
# quartier      0
# ville         0
# pays          0
# dtype: int64
# volailles
#  page-link      0
# name           0
# price          0
# adresse        0
# image-link     0
# devise         0
# quartier       0
# ville         10
# pays           0
# dtype: int64
# other-animals
#  page-link     0
# name          0
# price         0
# adresse       0
# image-link    0
# devise        0
# quartier      0
# ville         5
# pays          0
# dtype: int64

# %%
chiens = pd.read_csv("./data/chiens.csv")
moutons = pd.read_csv("./data/moutons.csv")
volailles = pd.read_csv("./data/volailles.csv")
other_animals = pd.read_csv("./data/other-animals.csv")

# %% [markdown]
# # Sauvegarde des donnees nettoyees

# %%
for key, df in all_df.items():
    df.to_csv(f"./data-cleaned/{key}.csv", index=False)
