# %% [markdown]
# # Visualization des donnees netoyee

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Je lis mes datasets

vehicules = pd.read_csv("./data-cleaned/vehicules.csv")
motos = pd.read_csv("./data-cleaned/motos.csv")
telephones = pd.read_csv("./data-cleaned/telephones.csv")
locations_vehicules = pd.read_csv("./data-cleaned/locations_vehicules.csv")

# %% [markdown]
# ## Afficher les vehicules en fonction de leurs adresse

# %%
plt.figure(figsize=(16, 8))
sns.countplot(data=vehicules, x="adresse",)
plt.xticks(rotation=90);

# %%
## Afficher les vehicules en fonction des prix

# %%
# vehicules["price"].dtype

# %%
fig, ax = plt.subplots(figsize=(8, 5))
ax.hist(vehicules["price"], bins=20, color='skyblue', edgecolor='black')
ax.set_xlabel("Prix")
ax.set_ylabel("Nombre d'articles")

# Afficher
plt.show()
